# %%
# Now, let's process the text to get in ready for analysis. We'll remove stopwords and save a new file with
# the cleaned text.

## LOWERCASE AND REMOVE STOPWORDS AND PUNCTUATION

# %%
import codecs
import nltk
from nltk.corpus import stopwords

# NLTK's default French stopwords
default_stopwords = set(nltk.corpus.stopwords.words('french'))

input_file = 'beauverie.txt' 

fp = codecs.open(input_file, 'r', 'utf-8')

words = nltk.word_tokenize(fp.read())

# Remove single-character tokens (mostly punctuation)
words = [word for word in words if len(word) > 1]

# Remove numbers
words = [word for word in words if not word.isnumeric()]

# Lowercase all words (default_stopwords are lowercase too)
words = [word.lower() for word in words]


# Remove stopwords
words = [word for word in words if word not in default_stopwords]

# Save our new file as 'cleaned_text.txt'
with open('cleaned_text.txt', 'w') as f:
    for item in words:
        f.write("%s\n" % item)

# %%
# We can remove words from a custom stopwords list, as well.

# %%
stop_words_lst = ['know', 'this']
s = "this is a test, you know"

import re
for w in stop_words_lst:
    pattern = r'\b'+w+r'\b'
    s = re.sub(pattern, '', s)

print (s)
# Out:
#  is a test, you

# %%
# Alternatively, we can use Spacy to remove stopwords.

# %%
import spacy
from spacy.lang.fr import French
from spacy.lang.fr.stop_words import STOP_WORDS

# Load the French tokenizer
nlp = French()

# Set the variable "text" as our chosen file and remove any new lines ('\n')
with open('beauverie.txt', 'r') as file:
    text = file.read().replace('\n', '')
    
# Convert the text to a Spacy document
my_doc = nlp(text)

# Create list of word tokens
token_list = []

# Tokenize our text and append the tokens to a new list, "token_list"
for token in my_doc:
   if token.is_punct == False:
       token_list.append(token.text.lower())  # make the words lowercase

# Create list of word tokens after removing stopwords
filtered_text =[]

# Iterate through the list and remove any stopwords
for word in token_list:
   lexeme = nlp.vocab[word]
   if lexeme.is_stop == False:
       filtered_text.append(word)

print(filtered_text)  

# Save the file as 'cleaned_text.txt'
with open('cleaned_text_spacy.txt', 'w') as f:
    for item in filtered_text:
        f.write("%s\n" % item)
# Out:
# ['avant-propos', 'pouvant', 'servir', 'mode', 'emploi', '<', 'p></p', '>', 'nie', 'pensée', 'claire', 'puisse', 'indicible', 'pourtant', 'apparence', 'contredit', 'y', 'intensité', 'douleur', 'corps', 'intéressé', 'y', 'participait', 'fût', '-ce', 'sanglot', '-t', '-il', 'aussitôt', 'réduit', 'cendres', 'y', 'sommet', 'douleur', 'vole', 'propres', 'ailes', 'y', 'intensité', 'pensée', 'mots', 'part', 'mots', 'conviennent', 'précision', 'pensée', 'larmes', 'degré', 'douleur', 'vague', 'innommable', 'précis', 'ineffable', 'vraiment', 'apparence', 'langage', 'exprime', 'précision', 'intensité', 'moyenne', 'pensée', 'moyenne', 'humanité', 'degré', 'intensité', 'intensité', 'consent', 'degré', 'précision', 'convient', 'arrivons', 'faire', 'entendre', 'clairement', 'outil', 'faut', 'accuser', 'langage', 'clair', 'suppose', 'conditions', 'parleur', 'sachant', 'veut', 'auditeur', 'état', 'veille', 'langue', 'commune', 'langage', 'clair', 'proposition', 'algébrique', 'claire', 'faut', 'contenu', 'réel', 'faut', 'élément', 'interlocuteurs', 'expérience', 'commune', 'chose', 'parlé', 'expérience', 'commune', 'réserve', 'or', 'confère', 'valeur', 'échange', 'monnaie', 'mots', 'réserve', 'expériences', 'communes', 'paroles', 'chèques', 'provision', 'algèbre', 'justement', 'vaste', 'opération', 'crédit', 'intellectuelle', 'faux-monnayage', 'légitime', 'avoué', 'fin', 'sens', 'chose', 'savoir', 'arithmétique', 'langage', 'clarté', 'contenu', 'dis', 'jour', '-là', 'pleuvait', 'faut', 'but', 'nécessité', 'langage', 'tombe', 'parlage', 'parlage', 'bavardage', 'bavardage', 'confusion', 'confusion', 'langues', 'hommes', 'expériences', 'communes', 'langue', 'échanger', 'fruits', 'confusion', 'devient', 'intolérable', 'invente', 'langues', 'universelles', 'claires', 'vides', 'mots', 'fausse', 'monnaie', 'gage', 'or', 'expérience', 'réelle', 'langues', 'grâce', 'enfance', 'gonflons', 'faux', 'savoirs', 'confusion', 'babel', 'stériles', 'espérantos', 'y', 'choisir', 'formes', 'incompréhension', 'seconde', 'essayer', 'décrire', 'partie', 'dialogue', 'laborieux', 'puissance', 'mots', 'faiblesse', 'pensée', '<', 'p></p', '>', 'iil', 'tard', 'bûmes', 'pensions', 'grand', 'temps', 'commencer', 'y', 'souvenait', 'disait', 'déjà', 'tard', 'savoir', 'venait', 'point', 'globe', 'vraiment', 'globe', 'cas', 'point', 'jour', 'mois', 'année', 'dépassait', 'soulève', 'questions', 'soif', 'soif', 'guette', 'occasions', 'boire', 'semblant', 'y', 'faire', 'attention', 'difficile', 'raconter', 'vécu', 'tentant', 'lorsqu’', 'rapporte', 'événements', 'passés', 'mettre', 'clarté', 'ordre', 'y', 'tentant', 'dangereux', 'devient', 'prématurément', 'philosophe', 'essayer', 'raconter', 'pensé', 'venu', 'paraît', 'chaotique', 'brumeux', 'prenez', 'courage', 'ensuite', 'ordonné', 'clair', 'ordre', 'clarté', 'récit', 'paraissaient', 'substance', 'rassurez', '-vous', 'terminerai', 'paroles', 'réconfortantes', 'iinous', 'étions', 'fumée', 'épaisse', 'cheminée', 'tirait', 'mal', 'feu', 'bois', 'vert', 'rabrouait', 'chandelles', 'dégageaient', 'sauce', 'suifeuse', 'air', 'nuages', 'tabac', 'couchaient', 'bancs', 'bleuâtres', 'hauteur', 'visage', 'savait', 'sûr', 'seuls', 'propos', 'grande', 'voix', 'fagots', 'appelions', 'langage', 'soiffards', 'élevée', 'sortait', 'effectivement', 'tas', 'fagots', 'caisses', 'biscuits', 'difficile', 'savoir', 'cause', 'fumée', 'fatigue', 'disait', 'microbe', 'allais', 'homme', 'réclame', 'âme', 'sœur', 'pleurniche', 'compagnie', 'âme', 'sœur', 'arrive', 'supporter', 'commence', 'frénétiser', 'devenir', 'objet', 'tiraillements', 'intestins', 'bon', 'sens', 'veut', 'veut', 'âme', 'sœur', 'arrive', 'scinde', 'bonjour', 'vieux', 'jette', 'bras', 'recolle', 'travers', 'prend', 'chose', 'quelqu’', 'avez', 'pourtant', 'chose', 'commun', 'solitude', 'dépend', 'trouva', 'souciait', 'voir', 'personnage', 'parlait', 'question', 'boire', 'bu', 'tasses', 'tord', 'boyau', 'infect', 'donné', 'soif', 'iiià', 'moment', 'mauvaise', 'humeur', 'comble', 'crois', 'souv ...
